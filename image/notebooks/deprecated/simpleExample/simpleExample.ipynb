# %%
from pymoab.core import Core  # meshdb
import pymoab.types as mt # moab types
from pydtk2 import *  # mapper
from ovcg import *  # fluid solver
from fesol import *  # FEM solver
from mpi4py import MPI  # fix openmpi with python
import numpy as np
from meshio.gmsh_io import read
from numpy import linalg as LA

# %%
# retrieve the interface grids and convert them into
# unstructure Q1 elements

g_f = Grids('inputs/fluid_quad.hdf')
grid_num = 0
indices = g_f.get_boundary_indices(grid=grid_num, side=1, axis=0)
# to get the geometry data, we need another instance in pyoverture
# the geometry class
gdata = Geometry(grid=grid_num, cg=g_f)
# get connectivity and vertices
conn_int_f = indices.generate_surface_connectivity(dim=2)
vert_int_f = gdata.get_vertices(indices)

# %%
vert_int_s, conn_int_s, _, phy_data, _ = read('inputs/solid_tri.msh')

# get the union of node ids on boundary of tag 5
temp = set()
for i in range(conn_int_s['line'].shape[0]):
    if phy_data['line']['gmsh:physical'][i] == 5:
        temp |= set(list(conn_int_s['line'][i]))

# make a list and table
temp = list(temp)
temp.sort()
vert_int_s = vert_int_s[temp] # vertices
table = {}
for i in range(len(temp)):
    table[temp[i]] = i
temp = []
for i in range(conn_int_s['line'].shape[0]):
    if phy_data['line']['gmsh:physical'][i] == 5:
        temp.append([])
        for j in conn_int_s['line'][i]:
            temp[-1].append(table[j])
conn_int_s = temp

# %%
# convert integers to uint64 for both fluid and solid, this is for moab
conn_int_f = np.array(conn_int_f, dtype=np.uint64)
conn_int_s = np.array(conn_int_s, dtype=np.uint64)

# also, convert fluid vertices to 3D
temp = np.zeros(shape=(vert_int_f.shape[0], 3))
temp[:, 0:2] = vert_int_f
vert_int_f = temp

# %%
# fluid interface meshdb
mdb_int_f = Core()
vert_int_f_range = mdb_int_f.create_vertices(vert_int_f.flatten())
conn_int_f[:] += vert_int_f_range[0] # adjust connectivity, for this case, just add 1
mdb_int_f.create_elements(mt.MBEDGE, conn_int_f)

# tags, where T for temperature and F for flux
tag_int_f = mdb_int_f.tag_get_handle(
    'intTf',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True)
T_int_f = np.zeros(vert_int_f.shape[0])
mdb_int_f.tag_set_data(tag_int_f, vert_int_f_range, T_int_f)
flux_tag_f = mdb_int_f.tag_get_handle(
    'intFf', size=1, tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE, create_if_missing=True)
flux_int_f = np.zeros(vert_int_f.shape[0])
mdb_int_f.tag_set_data(flux_tag_f, vert_int_f_range, flux_int_f)

# %%
# solid interface meshdb
mdb_int_s = Core()
vert_int_s_range = mdb_int_s.create_vertices(vert_int_s.flatten())
conn_int_s[:] += vert_int_s_range[0]
mdb_int_s.create_elements(mt.MBEDGE, conn_int_s)

# tags, where T for temperature and F for flux
tag_int_s = mdb_int_s.tag_get_handle(
    'intTs',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True)
T_int_s = np.zeros(vert_int_s.shape[0])
mdb_int_s.tag_set_data(tag_int_s, vert_int_s_range, T_int_s)
flux_tag_s = mdb_int_s.tag_get_handle(
    'intFs', size=1, tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE, create_if_missing=True)
flux_int_s = np.zeros(vert_int_s.shape[0])
mdb_int_s.tag_set_data(flux_tag_s, vert_int_s_range, flux_int_s)

# %%
# configure mappers, DTK uses RBFs, the radius should not be small
# otherwise, you may not have enough neighborhood for the fitting
radius = 0.4

# create solid manager
dtk_mnr_s = DTK2MoabManager(mdb_int_s)
dtk_mnr_s.register_tags(['intTs', 'intFs'])

# create fluid manager
dtk_mnr_f = DTK2MoabManager(mdb_int_f)
dtk_mnr_f.register_tags(['intTf', 'intFf'])

# solid temperature to fluid mapper
sT2f_mapper = DTK2Mapper(source=dtk_mnr_s, target=dtk_mnr_f, r=radius)
sT2f_mapper.register_coupled_tags('intTs', 'intTf')

# fluid flux to solid mapper
fF2s_mapper = DTK2Mapper(source=dtk_mnr_f, target=dtk_mnr_s, r=radius)
fF2s_mapper.register_coupled_tags('intFf', 'intFs')

# %%
# FEM solver
kappa_s = 0.7
specific_heat = 0.485
solver_s = HeatSolver(kappa=kappa_s, c=specific_heat)
solver_s.load_mesh('inputs/solid_tri.msh')
solver_s.set_initial_condition(0.0)
solver_s.set_boundary(2, 0.0, boundary_type='Neumann') # bot
solver_s.set_boundary(3, 1.0) # right
solver_s.set_boundary(4, 0.0, boundary_type='Neumann') # top
solver_s.set_boundary(5, 0.0, boundary_type='Neumann') # interface
solver_s.set_source(0.0) # forcing term

# init
solver_s.init_solver()

solver_s.output_file = 'outputs/solid.pvd'

# %%
# fluid solver
solver_f = Cgins()
solver_f.read_cmd('inputs/fluidCgins.cmd')
solver_f.init_grid()
solver_f.init_temperature_interface(grid=grid_num, side=1, axis=0)  # must do this!
solver_f.init_solver(debug=0)

kappa_f = solver_f.get_thermal_conductivity()
assert kappa_f > 0.0

# %%
inall = g_f.get_indices(0)
vertsall = gdata.get_vertices(inall)
connall = inall.generate_volume_connectivity(2)
temp = np.zeros(shape=(vertsall.shape[0],3), dtype=np.float64)
temp[:,0:2] = vertsall
vertsall = temp
mdbF = Core()
vr = mdbF.create_vertices(vertsall.flatten())
connall[:] += vr[0]
connall = np.array(connall, dtype=np.uint64)
mdbF.create_elements(mt.MBQUAD, connall)
tagF = mdbF.tag_get_handle(
    'fT',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True
)

# %%
# coupling
Tfinal = 1.0
N = 200
dt = Tfinal / N
t = 0.0
tfprevInt = np.zeros_like(T_int_f)
omega = 0.5 # relaxation parameter

# %%
for i in range(N):
    t += dt
    solver_f.backup_current_solutions()
    solver_s.backup()
    
    count = 0
    
    while 1:
        count = count + 1
        tfprevInt[:] = T_int_f

    ##########
    # FLUID I
    ##########
    
    # advance
        solver_f.advance(t, dt)
    # get fluid interface heat flux
        flux_int_f[:] = solver_f.get_normal_heat_flux_interface(grid=grid_num, side=1, axis=0)
    # scale
        flux_int_f[:] *= kappa_f

    ###########
    # MAPPING
    ###########
    
    # put to meshdb
        mdb_int_f.tag_set_data(flux_tag_f, vert_int_f_range, flux_int_f)
    # transfer
        fF2s_mapper.apply('intFf', 'intFs')

    ##########
    # SOLID
    ##########
    
    # get data from meshdb
        flux_int_s[:] = mdb_int_s.tag_get_data(flux_tag_s, vert_int_s_range, True)
    # solid update the heat flux interface, remind the tag is 5
    # cht_interface indicates that this value is given by CHT interface
    # so internally, it will take care of scaling and normal directions
        solver_s.update_flux_interface(5, flux_int_s, cht_interface=True)
    # advance
        solver_s.advance(dt, t)
    # get temperature
        T_int_s[:] = solver_s.get_solutions(where='boundary', tag=5)

    ###########
    # MAPPING
    ###########
    
    # put to meshdb
        mdb_int_s.tag_set_data(tag_int_s, vert_int_s_range, T_int_s)
    # transfer
        sT2f_mapper.apply('intTs', 'intTf')

    ##########
    # FLUID II
    ##########
    
    # get data from meshdb
        T_int_f[:] = mdb_int_f.tag_get_data(tag_int_f, vert_int_f_range, True)
        T_int_f[:] = (1.0-omega)*T_int_f+omega*tfprevInt
    # fluid updating the temperature boundary condition
        solver_f.put_temperature_interface(0, 1, 0, T_int_f)
        
        err = T_int_f-tfprevInt
        err = LA.norm(err) # TODO should be relative error right?
        if err < 1e-3 or count >= 100:
            break
        else:
            solver_f.restore_previous_solutions()
            solver_s.restore()
    
    ##########
    # OUTPUTS
    ##########

    print('error=%f, step=%i, iterations=%i' % (err, i, count))
    solver_s.write()
    fT = solver_f.get_temperature(0, inall)
    mdbF.tag_set_data(tagF, vr, fT)
    mdbF.write_file('outputs/fluid%i.vtk' % i)
# Out:
# error=0.000000, step=0, iterations=1
# error=0.000002, step=1, iterations=1
# error=0.000017, step=2, iterations=1
# error=0.000113, step=3, iterations=1
# error=0.000525, step=4, iterations=1
# error=0.000229, step=5, iterations=2
# error=0.000566, step=6, iterations=2
# error=0.000154, step=7, iterations=3
# error=0.000250, step=8, iterations=3
# error=0.000348, step=9, iterations=3
# error=0.000447, step=10, iterations=3
# error=0.000533, step=11, iterations=3
# error=0.000610, step=12, iterations=3
# error=0.000673, step=13, iterations=3
# error=0.000726, step=14, iterations=3
# error=0.000767, step=15, iterations=3
# error=0.000799, step=16, iterations=3
# error=0.000822, step=17, iterations=3
# error=0.000838, step=18, iterations=3
# error=0.000848, step=19, iterations=3
# error=0.000853, step=20, iterations=3
# error=0.000853, step=21, iterations=3
# error=0.000850, step=22, iterations=3
# error=0.000844, step=23, iterations=3
# error=0.000835, step=24, iterations=3
# error=0.000825, step=25, iterations=3
# error=0.000813, step=26, iterations=3
# error=0.000799, step=27, iterations=3
# error=0.000785, step=28, iterations=3
# error=0.000770, step=29, iterations=3
# error=0.000754, step=30, iterations=3
# error=0.000738, step=31, iterations=3
# error=0.000721, step=32, iterations=3
# error=0.000705, step=33, iterations=3
# error=0.000688, step=34, iterations=3
# error=0.000672, step=35, iterations=3
# error=0.000655, step=36, iterations=3
# error=0.000639, step=37, iterations=3
# error=0.000622, step=38, iterations=3
# error=0.000606, step=39, iterations=3
# error=0.000591, step=40, iterations=3
# error=0.000575, step=41, iterations=3
# error=0.000560, step=42, iterations=3
# error=0.000545, step=43, iterations=3
# error=0.000531, step=44, iterations=3
# error=0.000516, step=45, iterations=3
# error=0.000503, step=46, iterations=3
# error=0.000489, step=47, iterations=3
# error=0.000476, step=48, iterations=3
# error=0.000463, step=49, iterations=3
# error=0.000450, step=50, iterations=3
# error=0.000438, step=51, iterations=3
# error=0.000426, step=52, iterations=3
# error=0.000415, step=53, iterations=3
# error=0.000403, step=54, iterations=3
# error=0.000392, step=55, iterations=3
# error=0.000382, step=56, iterations=3
# error=0.000371, step=57, iterations=3
# error=0.000361, step=58, iterations=3
# error=0.000351, step=59, iterations=3
# error=0.000342, step=60, iterations=3
# error=0.000333, step=61, iterations=3
# error=0.000323, step=62, iterations=3
# error=0.000315, step=63, iterations=3
# error=0.000306, step=64, iterations=3
# error=0.000298, step=65, iterations=3
# error=0.000290, step=66, iterations=3
# error=0.000282, step=67, iterations=3
# error=0.000275, step=68, iterations=3
# error=0.000267, step=69, iterations=3
# error=0.000260, step=70, iterations=3
# error=0.000253, step=71, iterations=3
# error=0.000246, step=72, iterations=3
# error=0.000240, step=73, iterations=3
# error=0.000233, step=74, iterations=3
# error=0.000227, step=75, iterations=3
# error=0.000221, step=76, iterations=3
# error=0.000215, step=77, iterations=3
# error=0.000210, step=78, iterations=3
# error=0.000204, step=79, iterations=3
# error=0.000199, step=80, iterations=3
# error=0.000193, step=81, iterations=3
# error=0.000188, step=82, iterations=3
# error=0.000183, step=83, iterations=3
# error=0.000179, step=84, iterations=3
# error=0.000174, step=85, iterations=3
# error=0.000169, step=86, iterations=3
# error=0.000165, step=87, iterations=3
# error=0.000161, step=88, iterations=3
# error=0.000157, step=89, iterations=3
# error=0.000153, step=90, iterations=3
# error=0.000988, step=91, iterations=2
# error=0.000973, step=92, iterations=2
# error=0.000966, step=93, iterations=2
# error=0.000930, step=94, iterations=2
# error=0.000911, step=95, iterations=2
# error=0.000884, step=96, iterations=2
# error=0.000864, step=97, iterations=2
# error=0.000840, step=98, iterations=2
# error=0.000819, step=99, iterations=2
# error=0.000798, step=100, iterations=2
# error=0.000778, step=101, iterations=2
# error=0.000758, step=102, iterations=2
# error=0.000739, step=103, iterations=2
# error=0.000720, step=104, iterations=2
# error=0.000702, step=105, iterations=2
# error=0.000684, step=106, iterations=2
# error=0.000667, step=107, iterations=2
# error=0.000650, step=108, iterations=2
# error=0.000634, step=109, iterations=2
# error=0.000618, step=110, iterations=2
# error=0.000603, step=111, iterations=2
# error=0.000588, step=112, iterations=2
# error=0.000573, step=113, iterations=2
# error=0.000559, step=114, iterations=2
# error=0.000545, step=115, iterations=2
# error=0.000531, step=116, iterations=2
# error=0.000518, step=117, iterations=2
# error=0.000505, step=118, iterations=2
# error=0.000493, step=119, iterations=2
# error=0.000481, step=120, iterations=2
# error=0.000469, step=121, iterations=2
# error=0.000458, step=122, iterations=2
# error=0.000446, step=123, iterations=2
# error=0.000435, step=124, iterations=2
# error=0.000425, step=125, iterations=2
# error=0.000415, step=126, iterations=2
# error=0.000404, step=127, iterations=2
# error=0.000395, step=128, iterations=2
# error=0.000385, step=129, iterations=2
# error=0.000376, step=130, iterations=2
# error=0.000367, step=131, iterations=2
# error=0.000358, step=132, iterations=2
# error=0.000349, step=133, iterations=2
# error=0.000341, step=134, iterations=2
# error=0.000333, step=135, iterations=2
# error=0.000325, step=136, iterations=2
# error=0.000317, step=137, iterations=2
# error=0.000309, step=138, iterations=2
# error=0.000302, step=139, iterations=2
# error=0.000295, step=140, iterations=2
# error=0.000288, step=141, iterations=2
# error=0.000281, step=142, iterations=2
# error=0.000274, step=143, iterations=2
# error=0.000268, step=144, iterations=2
# error=0.000261, step=145, iterations=2
# error=0.000255, step=146, iterations=2
# error=0.000249, step=147, iterations=2
# error=0.000243, step=148, iterations=2
# error=0.000238, step=149, iterations=2
# error=0.000232, step=150, iterations=2
# error=0.000227, step=151, iterations=2
# error=0.000221, step=152, iterations=2
# error=0.000216, step=153, iterations=2
# error=0.000211, step=154, iterations=2
# error=0.000206, step=155, iterations=2
# error=0.000201, step=156, iterations=2
# error=0.000196, step=157, iterations=2
# error=0.000192, step=158, iterations=2
# error=0.000187, step=159, iterations=2
# error=0.000183, step=160, iterations=2
# error=0.000179, step=161, iterations=2
# error=0.000175, step=162, iterations=2
# error=0.000171, step=163, iterations=2
# error=0.000167, step=164, iterations=2
# error=0.000163, step=165, iterations=2
# error=0.000159, step=166, iterations=2
# error=0.000155, step=167, iterations=2
# error=0.000152, step=168, iterations=2
# error=0.000148, step=169, iterations=2
# error=0.000145, step=170, iterations=2
# error=0.000142, step=171, iterations=2
# error=0.000996, step=172, iterations=1
# error=0.000144, step=173, iterations=2
# error=0.000150, step=174, iterations=2
# error=0.000852, step=175, iterations=1
# error=0.000139, step=176, iterations=2
# error=0.000964, step=177, iterations=1
# error=0.000885, step=178, iterations=1
# error=0.000146, step=179, iterations=2
# error=0.000843, step=180, iterations=1
# error=0.000838, step=181, iterations=1
# error=0.000950, step=182, iterations=1
# error=0.000870, step=183, iterations=1
# error=0.000893, step=184, iterations=1
# error=0.000836, step=185, iterations=1
# error=0.000840, step=186, iterations=1
# error=0.000800, step=187, iterations=1
# error=0.000796, step=188, iterations=1
# error=0.000766, step=189, iterations=1
# error=0.000757, step=190, iterations=1
# error=0.000732, step=191, iterations=1
# error=0.000721, step=192, iterations=1
# error=0.000700, step=193, iterations=1
# error=0.000687, step=194, iterations=1
# error=0.000669, step=195, iterations=1
# error=0.000656, step=196, iterations=1
# error=0.000639, step=197, iterations=1
# error=0.000626, step=198, iterations=1
# error=0.000610, step=199, iterations=1
