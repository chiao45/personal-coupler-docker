# %%
from pymoab.core import Core  # meshdb
import pymoab.types as mt # moab types
from pydtk2 import *  # mapper
from ovcg import *  # fluid solver
from fesol import *  # FEM solver
from mpi4py import MPI  # fix openmpi with python
import numpy as np
from meshio.gmsh_io import read
from numpy import linalg as LA

# %%
# create mapping
f2s = np.empty(64, dtype=int)
s2f = np.empty(64, dtype=int)
# this is done offline!
f2s[0] = 0
f2s[-1] = 1
for i in range(62):
    f2s[i+1] = 62-i+1

# %%
s2f[0] = 0
s2f[1] = 63
for i in range(62):
    s2f[i+2] = 62-i

# %%
# retrieve the interface grids and convert them into
# unstructure Q1 elements

g_f = Grids('inputs/fluid_quad.hdf')
grid_num = 0
indices = g_f.get_boundary_indices(grid=grid_num, side=1, axis=0)
# to get the geometry data, we need another instance in pyoverture
# the geometry class
gdata = Geometry(grid=grid_num, cg=g_f)
# get connectivity and vertices
conn_int_f = indices.generate_surface_connectivity(dim=2)
vert_int_f = gdata.get_vertices(indices)

# %%
vert_int_s, conn_int_s, _, phy_data, _ = read('inputs/solid.msh')

# get the union of node ids on boundary of tag 5
temp = set()
for i in range(conn_int_s['line'].shape[0]):
    if phy_data['line']['gmsh:physical'][i] == 5:
        temp |= set(list(conn_int_s['line'][i]))

# make a list and table
temp = list(temp)
temp.sort()
vert_int_s = vert_int_s[temp] # vertices
table = {}
for i in range(len(temp)):
    table[temp[i]] = i
temp = []
for i in range(conn_int_s['line'].shape[0]):
    if phy_data['line']['gmsh:physical'][i] == 5:
        temp.append([])
        for j in conn_int_s['line'][i]:
            temp[-1].append(table[j])
conn_int_s = temp

# %%
# convert integers to uint64 for both fluid and solid, this is for moab
conn_int_f = np.array(conn_int_f, dtype=np.uint64)
conn_int_s = np.array(conn_int_s, dtype=np.uint64)

# also, convert fluid vertices to 3D
temp = np.zeros(shape=(vert_int_f.shape[0], 3))
temp[:, 0:2] = vert_int_f
vert_int_f = temp

# %%
# fluid interface meshdb
mdb_int_f = Core()
vert_int_f_range = mdb_int_f.create_vertices(vert_int_f.flatten())
conn_int_f[:] += vert_int_f_range[0] # adjust connectivity, for this case, just add 1
mdb_int_f.create_elements(mt.MBEDGE, conn_int_f)

# tags, where T for temperature and F for flux
tag_int_f = mdb_int_f.tag_get_handle(
    'intTf',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True)
T_int_f = np.zeros(vert_int_f.shape[0])
mdb_int_f.tag_set_data(tag_int_f, vert_int_f_range, T_int_f)
flux_tag_f = mdb_int_f.tag_get_handle(
    'intFf', size=1, tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE, create_if_missing=True)
flux_int_f = np.zeros(vert_int_f.shape[0])
mdb_int_f.tag_set_data(flux_tag_f, vert_int_f_range, flux_int_f)

# %%
# solid interface meshdb
mdb_int_s = Core()
vert_int_s_range = mdb_int_s.create_vertices(vert_int_s.flatten())
conn_int_s[:] += vert_int_s_range[0]
mdb_int_s.create_elements(mt.MBEDGE, conn_int_s)

# tags, where T for temperature and F for flux
tag_int_s = mdb_int_s.tag_get_handle(
    'intTs',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True)
T_int_s = np.zeros(vert_int_s.shape[0])
mdb_int_s.tag_set_data(tag_int_s, vert_int_s_range, T_int_s)
flux_tag_s = mdb_int_s.tag_get_handle(
    'intFs', size=1, tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE, create_if_missing=True)
flux_int_s = np.zeros(vert_int_s.shape[0])
mdb_int_s.tag_set_data(flux_tag_s, vert_int_s_range, flux_int_s)

# %%
# # configure mappers, DTK uses RBFs, the radius should not be small
# # otherwise, you may not have enough neighborhood for the fitting
# radius = 0.4

# # create solid manager
# dtk_mnr_s = DTK2MoabManager(mdb_int_s)
# dtk_mnr_s.register_tags(['intTs', 'intFs'])

# # create fluid manager
# dtk_mnr_f = DTK2MoabManager(mdb_int_f)
# dtk_mnr_f.register_tags(['intTf', 'intFf'])

# # solid temperature to fluid mapper
# sT2f_mapper = DTK2Mapper(source=dtk_mnr_s, target=dtk_mnr_f, r=radius)
# sT2f_mapper.register_coupled_tags('intTs', 'intTf')

# # fluid flux to solid mapper
# fF2s_mapper = DTK2Mapper(source=dtk_mnr_f, target=dtk_mnr_s, r=radius)
# fF2s_mapper.register_coupled_tags('intFf', 'intFs')

# %%
# FEM solver
kappa_s = 0.7
specific_heat = 0.485
solver_s = HeatSolver(kappa=kappa_s, c=specific_heat)
solver_s.load_mesh('inputs/solid.msh')
solver_s.set_initial_condition(0.0)
solver_s.set_boundary(2, 0.0, boundary_type='Neumann') # bot
solver_s.set_boundary(3, 1.0) # right
solver_s.set_boundary(4, 0.0, boundary_type='Neumann') # top
solver_s.set_boundary(5, 0.0, boundary_type='Neumann') # interface
solver_s.set_source(0.0) # forcing term
s2f
# init
solver_s.init_solver()

solver_s.output_file = 'outputs/solid.pvd'

# %%
# fluid solver
solver_f = Cgins()
solver_f.read_cmd('inputs/fluidCgins.cmd')
solver_f.init_grid()
solver_f.init_temperature_interface(grid=grid_num, side=1, axis=0)  # must do this!
solver_f.init_solver(debug=0)

kappa_f = solver_f.get_thermal_conductivity()
assert kappa_f > 0.0

# %%
inall = g_f.get_indices(0)
vertsall = gdata.get_vertices(inall)
connall = inall.generate_volume_connectivity(2)
temp = np.zeros(shape=(vertsall.shape[0],3), dtype=np.float64)
temp[:,0:2] = vertsall
vertsall = temp
mdbF = Core()

# %%
vr = mdbF.create_vertices(vertsall.flatten())
connall[:] += vr[0]
connall = np.array(connall, dtype=np.uint64)

# %%
mdbF.create_elements(mt.MBQUAD, connall)
# Out:
# b'\tQuad 1 - 3969\n'

# %%
tagF = mdbF.tag_get_handle(
    'fT',
    size=1,
    tag_type=mt.MB_TYPE_DOUBLE,
    storage_type=mt.MB_TAG_DENSE,
    create_if_missing=True
)

# %%
# coupling
Tfinal = 1.0
N = 200
dt = Tfinal / N
t = 0.0
tfprevInt = np.zeros_like(T_int_f)
omega = 0.5 # relaxation parameter

# %%
for i in range(N):
    t += dt
    
    count = 0
    
    ##########
    # FLUID I
    ##########
    solver_f.backup_current_solutions()
    solver_s.backup()
    while True:
        count = count + 1
        tfprevInt[:] = T_int_f
    
    # advance
        solver_f.advance(t, dt)
    # get fluid interface heat flux
        flux_int_f[:] = solver_f.get_normal_heat_flux_interface(grid=grid_num, side=1, axis=0)
    # scale
        flux_int_f[:] *= kappa_f

    ###########
    # MAPPING
    ###########
    
#     # put to meshdb
#     mdb_int_f.tag_set_data(flux_tag_f, vert_int_f_range, flux_int_f)
#     # transfer
#     fF2s_mapper.apply('intFf', 'intFs')
        flux_int_s[:] = flux_int_f[f2s]

    ##########
    # SOLID
    ##########
    
    # get data from meshdb
#    flux_int_s[:] = mdb_int_s.tag_get_data(flux_tag_s, vert_int_s_range, True)
    # solid update the heat flux interface, remind the tag is 5
    # cht_interface indicates that this value is given by CHT interface
    # so internally, it will take care of scaling and normal directions
        solver_s.update_flux_interface(5, flux_int_s, cht_interface=True)
    # advance
        solver_s.advance(dt, t)
    # get temperature
        T_int_s[:] = solver_s.get_solutions(where='boundary', tag=5)

    ###########
    # MAPPING
    ###########
    
#     # put to meshdb
#     mdb_int_s.tag_set_data(tag_int_s, vert_int_s_range, T_int_s)
#     # transfer
#     sT2f_mapper.apply('intTs', 'intTf')

    ##########
    # FLUID II
    ##########
    
    # get data from meshdb
#    T_int_f[:] = mdb_int_f.tag_get_data(tag_int_f, vert_int_f_range, True)
    # fluid updating the temperature boundary condition
        T_int_f[:] = T_int_s[s2f]
        T_int_f[:] = (1.0-omega)*T_int_f+omega*tfprevInt
        solver_f.put_temperature_interface(0, 1, 0, T_int_f)
        
        err = T_int_f-tfprevInt
        err = LA.norm(err) # TODO should be relative error right?
        if err < 1e-3 or count >= 100:
            break
        else:
            solver_f.restore_previous_solutions()
            solver_s.restore()
    
    ##########
    # OUTPUTS
    ##########
    print('error=%f, step=%i, iterations=%i' % (err, i, count))
    solver_s.write()
    fT = solver_f.get_temperature(0, inall)
    mdbF.tag_set_data(tagF, vr, fT)
    mdbF.write_file('outputs/fluid%i.vtk' % i)
# Out:
# error=0.000000, step=0, iterations=1
# error=0.000008, step=1, iterations=1
# error=0.000060, step=2, iterations=1
# error=0.000301, step=3, iterations=1
# error=0.000120, step=4, iterations=2
# error=0.000325, step=5, iterations=2
# error=0.000667, step=6, iterations=2
# error=0.000134, step=7, iterations=3
# error=0.000203, step=8, iterations=3
# error=0.000273, step=9, iterations=3
# error=0.000345, step=10, iterations=3
# error=0.000408, step=11, iterations=3
# error=0.000464, step=12, iterations=3
# error=0.000512, step=13, iterations=3
# error=0.000552, step=14, iterations=3
# error=0.000584, step=15, iterations=3
# error=0.000610, step=16, iterations=3
# error=0.000630, step=17, iterations=3
# error=0.000645, step=18, iterations=3
# error=0.000656, step=19, iterations=3
# error=0.000663, step=20, iterations=3
# error=0.000666, step=21, iterations=3
# error=0.000668, step=22, iterations=3
# error=0.000667, step=23, iterations=3
# error=0.000664, step=24, iterations=3
# error=0.000660, step=25, iterations=3
# error=0.000655, step=26, iterations=3
# error=0.000648, step=27, iterations=3
# error=0.000641, step=28, iterations=3
# error=0.000633, step=29, iterations=3
# error=0.000625, step=30, iterations=3
# error=0.000616, step=31, iterations=3
# error=0.000607, step=32, iterations=3
# error=0.000598, step=33, iterations=3
# error=0.000589, step=34, iterations=3
# error=0.000579, step=35, iterations=3
# error=0.000570, step=36, iterations=3
# error=0.000561, step=37, iterations=3
# error=0.000551, step=38, iterations=3
# error=0.000542, step=39, iterations=3
# error=0.000533, step=40, iterations=3
# error=0.000524, step=41, iterations=3
# error=0.000515, step=42, iterations=3
# error=0.000506, step=43, iterations=3
# error=0.000497, step=44, iterations=3
# error=0.000488, step=45, iterations=3
# error=0.000480, step=46, iterations=3
# error=0.000472, step=47, iterations=3
# error=0.000464, step=48, iterations=3
# error=0.000456, step=49, iterations=3
# error=0.000448, step=50, iterations=3
# error=0.000440, step=51, iterations=3
# error=0.000433, step=52, iterations=3
# error=0.000426, step=53, iterations=3
# error=0.000418, step=54, iterations=3
# error=0.000411, step=55, iterations=3
# error=0.000405, step=56, iterations=3
# error=0.000398, step=57, iterations=3
# error=0.000391, step=58, iterations=3
# error=0.000385, step=59, iterations=3
# error=0.000379, step=60, iterations=3
# error=0.000373, step=61, iterations=3
# error=0.000367, step=62, iterations=3
# error=0.000361, step=63, iterations=3
# error=0.000355, step=64, iterations=3
# error=0.000350, step=65, iterations=3
# error=0.000344, step=66, iterations=3
# error=0.000339, step=67, iterations=3
# error=0.000334, step=68, iterations=3
# error=0.000329, step=69, iterations=3
# error=0.000324, step=70, iterations=3
# error=0.000319, step=71, iterations=3
# error=0.000314, step=72, iterations=3
# error=0.000310, step=73, iterations=3
# error=0.000305, step=74, iterations=3
# error=0.000301, step=75, iterations=3
# error=0.000296, step=76, iterations=3
# error=0.000292, step=77, iterations=3
# error=0.000288, step=78, iterations=3
# error=0.000284, step=79, iterations=3
# error=0.000280, step=80, iterations=3
# error=0.000276, step=81, iterations=3
# error=0.000272, step=82, iterations=3
# error=0.000268, step=83, iterations=3
# error=0.000265, step=84, iterations=3
# error=0.000261, step=85, iterations=3
# error=0.000258, step=86, iterations=3
# error=0.000254, step=87, iterations=3
# error=0.000251, step=88, iterations=3
# error=0.000248, step=89, iterations=3
# error=0.000244, step=90, iterations=3
# error=0.000241, step=91, iterations=3
# error=0.000238, step=92, iterations=3
# error=0.000235, step=93, iterations=3
# error=0.000232, step=94, iterations=3
# error=0.000229, step=95, iterations=3
# error=0.000226, step=96, iterations=3
# error=0.000224, step=97, iterations=3
# error=0.000221, step=98, iterations=3
# error=0.000218, step=99, iterations=3
# error=0.000216, step=100, iterations=3
# error=0.000213, step=101, iterations=3
# error=0.000210, step=102, iterations=3
# error=0.000208, step=103, iterations=3
# error=0.000206, step=104, iterations=3
# error=0.000203, step=105, iterations=3
# error=0.000201, step=106, iterations=3
# error=0.000199, step=107, iterations=3
# error=0.000196, step=108, iterations=3
# error=0.000194, step=109, iterations=3
# error=0.000192, step=110, iterations=3
# error=0.000190, step=111, iterations=3
# error=0.000188, step=112, iterations=3
# error=0.000186, step=113, iterations=3
# error=0.000184, step=114, iterations=3
# error=0.000182, step=115, iterations=3
# error=0.000180, step=116, iterations=3
# error=0.000178, step=117, iterations=3
# error=0.000176, step=118, iterations=3
# error=0.000174, step=119, iterations=3
# error=0.000172, step=120, iterations=3
# error=0.000170, step=121, iterations=3
# error=0.000169, step=122, iterations=3
# error=0.000167, step=123, iterations=3
# error=0.000165, step=124, iterations=3
# error=0.000164, step=125, iterations=3
# error=0.000162, step=126, iterations=3
# error=0.000160, step=127, iterations=3
# error=0.000159, step=128, iterations=3
# error=0.000157, step=129, iterations=3
# error=0.000156, step=130, iterations=3
# error=0.000154, step=131, iterations=3
# error=0.000153, step=132, iterations=3
# error=0.000151, step=133, iterations=3
# error=0.000150, step=134, iterations=3
# error=0.000148, step=135, iterations=3
# error=0.000147, step=136, iterations=3
# error=0.000146, step=137, iterations=3
# error=0.000144, step=138, iterations=3
# error=0.000143, step=139, iterations=3
# error=0.000142, step=140, iterations=3
# error=0.000140, step=141, iterations=3
# error=0.000139, step=142, iterations=3
# error=0.000138, step=143, iterations=3
# error=0.000137, step=144, iterations=3
# error=0.000136, step=145, iterations=3
# error=0.000134, step=146, iterations=3
# error=0.000133, step=147, iterations=3
# error=0.000132, step=148, iterations=3
# error=0.000131, step=149, iterations=3
# error=0.000130, step=150, iterations=3
# error=0.000129, step=151, iterations=3
# error=0.000128, step=152, iterations=3
# error=0.000127, step=153, iterations=3
# error=0.000126, step=154, iterations=3
# error=0.000125, step=155, iterations=3
# error=0.000124, step=156, iterations=3
# error=0.000123, step=157, iterations=3
# error=0.000122, step=158, iterations=3
# error=0.000121, step=159, iterations=3
# error=0.000120, step=160, iterations=3
# error=0.000119, step=161, iterations=3
# error=0.000118, step=162, iterations=3
# error=0.000117, step=163, iterations=3
# error=0.000116, step=164, iterations=3
# error=0.000115, step=165, iterations=3
# error=0.000114, step=166, iterations=3
# error=0.000113, step=167, iterations=3
# error=0.000995, step=168, iterations=2
# error=0.000986, step=169, iterations=2
# error=0.000114, step=170, iterations=3
# error=0.000980, step=171, iterations=2
# error=0.000957, step=172, iterations=2
# error=0.000987, step=173, iterations=2
# error=0.000955, step=174, iterations=2
# error=0.000965, step=175, iterations=2
# error=0.000945, step=176, iterations=2
# error=0.000949, step=177, iterations=2
# error=0.000933, step=178, iterations=2
# error=0.000935, step=179, iterations=2
# error=0.000922, step=180, iterations=2
# error=0.000921, step=181, iterations=2
# error=0.000910, step=182, iterations=2
# error=0.000908, step=183, iterations=2
# error=0.000899, step=184, iterations=2
# error=0.000896, step=185, iterations=2
# error=0.000887, step=186, iterations=2
# error=0.000884, step=187, iterations=2
# error=0.000876, step=188, iterations=2
# error=0.000873, step=189, iterations=2
# error=0.000865, step=190, iterations=2
# error=0.000862, step=191, iterations=2
# error=0.000855, step=192, iterations=2
# error=0.000851, step=193, iterations=2
# error=0.000844, step=194, iterations=2
# error=0.000841, step=195, iterations=2
# error=0.000834, step=196, iterations=2
# error=0.000831, step=197, iterations=2
# error=0.000825, step=198, iterations=2
# error=0.000821, step=199, iterations=2
