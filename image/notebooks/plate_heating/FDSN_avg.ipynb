# %%
from ovcg import *
from fesol import *
import numpy as np
import scipy.io as sio
from interface import DynamicUnderRelaxation, InterfaceData, RelativeCovergenceMonitor, AbsCovergenceMonitor

# %%
k=20
# problem discription:
# basically, with a fixed Pr=0.01 and Re=500, the k is the ratio between
# kappa_s/kappa_f, where kappa stands for conductivity coefficient.
assert k == 1 or k == 5 or k == 20

use_relax = True
use_solid_steady = False

# tolerance setting
tol = 1e-6
if tol > 1e-1:
    print('The tolerance is too large, this may lead to instability or low quality results')

# %%
# since this is a matching interface, we can create
# exact interface nodes mappings.
# this step is done offline
inodes = 100
s2f = np.zeros(inodes, dtype=int)
f2s = s2f.copy()
s2f[1] = inodes-1
start = inodes-2
for i in range(inodes-2):
    s2f[i+2] = start
    start = start - 1
count = 0
for i in range(inodes):
    f2s[s2f[i]] = i

# %%
# fluid solver
interface_grid = 3
interface_side = 0
interface_axis = 1

T_f = 350.0

solverF = Cgins()
solverF.read_cmd('fluid_inputs/fluid_flat_plate%i.cmd' % k)
solverF.init_grid()
solverF.init_temperature_interface(
    grid=interface_grid,
    side=interface_side,
    axis=interface_axis
)
solverF.init_solver(debug=0, logname='fluid_outputs/dummy')
fluid_ofile = VtkFile('fluid_outputs/resFDSNavg%i.pvd' % k)

# %%
# solid solver
fixed_temp_tag = 2
adiabatic_tag = 3
interface_tag = 4

kappa = 100.0
rho = 1.0
Cp = 100.0
T_bot = 310.0

solverS = HeatSolver(kappa=kappa, rho=rho, Cp=Cp, steady=use_solid_steady, time_order=2)
solverS.output_file = 'solid_outputs/resFDSNavg%i.pvd' % k
solverS.load_mesh('solid_inputs/solid_plate.msh')
solverS.set_initial_condition(T_bot)
solverS.define_adiabatic_bd(tag=adiabatic_tag)
solverS.define_const_temperature_bd(tag=fixed_temp_tag, value=T_bot)
solverS.define_flux_interface(tag=interface_tag)
solverS.init_solver()

# %%
# coupling data and setups
fluxF = InterfaceData(size=inodes, value=0.0)
fluxS = InterfaceData(size=inodes, value=0.0)
tempF = InterfaceData(size=inodes, value=T_f)
tempS = InterfaceData(size=inodes, value=T_bot)
thetaT = InterfaceData(size=inodes, value=0.0)

under_relax = DynamicUnderRelaxation(init_omega=1.0)
conv_mntr = RelativeCovergenceMonitor(tol=tol)
conv_solution = AbsCovergenceMonitor(tol=1e-4)

# maximum pc steps allowed
max_pc_steps = 200

# %%
# coupling timing information, use fixed time step for now
# Tfinal = 1.0
# N = 100
# dt = Tfinal/N
Nmax = 8000
t = 0.0
dt = 0.05
avg_pc_iterations = 0.0
flog = open('FDSNavg%i.log' % k, mode='w')
flog.write('Fluid Dirichlet with solid Neumann setting, study case: %i\n' % k)
flog.close()
flog = open('FDSNavg%i.log' % k, mode='a')

temps_prev = tempS.curr.copy()
fluxf_prev = fluxF.curr.copy()

# %%
# begin to couple
for step in range(Nmax):
    t += dt
    
    pc_counts = 0
    
    # back up solutions
    solverF.backup_current_solutions()
    solverS.backup()
    
    temps_prev[:] = tempS.curr
    fluxf_prev[:] = fluxF.curr
    
    # mapping
    tempF.curr[:] = tempS.curr[s2f]
    
    solverF.put_temperature_interface(
        grid=interface_grid,
        side=interface_side,
        axis=interface_axis,
        data=tempF.curr
    )
    
    while True:
        # back up previous interface value
        tempF.backup()
        fluxF.backup()
        tempS.backup()
        
        # advance fluid
        solverF.advance(t=t, dt=dt)
        # retrieve fluid interface flux
        fluxF.curr[:] = solverF.get_heat_flux_interface(
            grid=interface_grid,
            side=interface_side,
            axis=interface_axis
        )
        
        # mapping
        fluxS.curr[:] = 0.5*(fluxF.curr[f2s]+fluxf_prev[f2s])
        # update solid flux interface
        solverS.update_flux_interface(interface_tag, fluxS.curr)
        
        # advance solid
        solverS.advance(t=t, dt=dt)
        # retrieve solid interface temperature
        tempS.curr[:] = solverS.get_interface_temperature(tag=interface_tag)
        
        # mapping
        tempF.curr[:] = tempS.curr[s2f]
        
        # update residual
        tempF.update_res()
        
        # test convergence
        is_conv = conv_mntr.determine_convergence(tempF)
        if is_conv or pc_counts >= max_pc_steps:
            break
        else:
            # if not converge, then underrelaxation and update to fluid then restore
            if use_relax:
                under_relax.determine_omega(tempF)
                under_relax.update_solution(tempF)
            solverF.put_temperature_interface(
                grid=interface_grid,
                side=interface_side,
                axis=interface_axis,
                data=0.5*(tempF.curr+temps_prev[s2f])
            )
            solverF.restore_previous_solutions()
            solverS.restore()
            pc_counts = pc_counts + 1

    # outputs
    msg = 'step=%i, pc_iterations=%i.' % (step, pc_counts)
    print(msg)
    flog.write(msg+'\n')
    avg_pc_iterations += pc_counts
    if step % 50 == 0 or step == Nmax-1:
        solverS.write()
        fluid_ofile.write(solverF, t)
    thetaT.backup()
    thetaT.curr[:] = (solverF.get_temperature_interface(3,0,1)-T_bot)/(T_f-T_bot)
    thetaT.update_res()
    is_conv = conv_solution.determine_convergence(thetaT)
    if is_conv:
        if step % 50 and step != Nmax-1:
            solverS.write()
            fluid_ofile.write(solverF, t)
        break
    
flog.close()
# Out:
# step=0, pc_iterations=8.
# step=1, pc_iterations=4.
# step=2, pc_iterations=4.
# step=3, pc_iterations=3.
# step=4, pc_iterations=3.
# step=5, pc_iterations=3.
# step=6, pc_iterations=3.
# step=7, pc_iterations=3.
# step=8, pc_iterations=3.
# step=9, pc_iterations=3.
# step=10, pc_iterations=3.
# step=11, pc_iterations=3.
# step=12, pc_iterations=3.
# step=13, pc_iterations=2.
# step=14, pc_iterations=2.
# step=15, pc_iterations=2.
# step=16, pc_iterations=2.
# step=17, pc_iterations=2.
# step=18, pc_iterations=2.
# step=19, pc_iterations=2.
# step=20, pc_iterations=2.
# step=21, pc_iterations=2.
# step=22, pc_iterations=2.
# step=23, pc_iterations=2.
# step=24, pc_iterations=2.
# step=25, pc_iterations=2.
# step=26, pc_iterations=2.
# step=27, pc_iterations=2.
# step=28, pc_iterations=2.
# step=29, pc_iterations=2.
# step=30, pc_iterations=2.
# step=31, pc_iterations=2.
# step=32, pc_iterations=3.
# step=33, pc_iterations=3.
# step=34, pc_iterations=3.
# step=35, pc_iterations=2.
# step=36, pc_iterations=2.
# step=37, pc_iterations=2.
# step=38, pc_iterations=2.
# step=39, pc_iterations=2.
# step=40, pc_iterations=2.
# step=41, pc_iterations=2.
# step=42, pc_iterations=2.
# step=43, pc_iterations=2.
# step=44, pc_iterations=3.
# step=45, pc_iterations=3.
# step=46, pc_iterations=3.
# step=47, pc_iterations=3.
# step=48, pc_iterations=3.
# step=49, pc_iterations=3.
# step=50, pc_iterations=2.
# step=51, pc_iterations=2.
# step=52, pc_iterations=2.
# step=53, pc_iterations=2.
# step=54, pc_iterations=2.
# step=55, pc_iterations=2.
# step=56, pc_iterations=2.
# step=57, pc_iterations=2.
# step=58, pc_iterations=2.
# step=59, pc_iterations=2.
# step=60, pc_iterations=2.
# step=61, pc_iterations=2.
# step=62, pc_iterations=2.
# step=63, pc_iterations=2.
# step=64, pc_iterations=2.
# step=65, pc_iterations=2.
# step=66, pc_iterations=2.
# step=67, pc_iterations=2.
# step=68, pc_iterations=2.
# step=69, pc_iterations=2.
# step=70, pc_iterations=2.
# step=71, pc_iterations=2.
# step=72, pc_iterations=2.
# step=73, pc_iterations=2.
# step=74, pc_iterations=2.
# step=75, pc_iterations=2.
# step=76, pc_iterations=2.
# step=77, pc_iterations=2.
# step=78, pc_iterations=2.
# step=79, pc_iterations=2.
# step=80, pc_iterations=2.
# step=81, pc_iterations=2.
# step=82, pc_iterations=2.
# step=83, pc_iterations=2.
# step=84, pc_iterations=2.
# step=85, pc_iterations=2.
# step=86, pc_iterations=2.
# step=87, pc_iterations=2.
# step=88, pc_iterations=2.
# step=89, pc_iterations=2.
# step=90, pc_iterations=2.
# step=91, pc_iterations=2.
# step=92, pc_iterations=2.
# step=93, pc_iterations=2.
# step=94, pc_iterations=2.
# step=95, pc_iterations=2.
# step=96, pc_iterations=2.
# step=97, pc_iterations=2.
# step=98, pc_iterations=2.
# step=99, pc_iterations=2.
# step=100, pc_iterations=2.
# step=101, pc_iterations=2.
# step=102, pc_iterations=2.
# step=103, pc_iterations=2.
# step=104, pc_iterations=2.
# step=105, pc_iterations=2.
# step=106, pc_iterations=2.
# step=107, pc_iterations=2.
# step=108, pc_iterations=2.
# step=109, pc_iterations=2.
# step=110, pc_iterations=2.
# step=111, pc_iterations=2.
# step=112, pc_iterations=2.
# step=113, pc_iterations=2.
# step=114, pc_iterations=2.
# step=115, pc_iterations=2.
# step=116, pc_iterations=2.
# step=117, pc_iterations=2.
# step=118, pc_iterations=2.
# step=119, pc_iterations=2.
# step=120, pc_iterations=2.
# step=121, pc_iterations=2.
# step=122, pc_iterations=2.
# step=123, pc_iterations=2.
# step=124, pc_iterations=2.
# step=125, pc_iterations=2.
# step=126, pc_iterations=2.
# step=127, pc_iterations=2.
# step=128, pc_iterations=2.
# step=129, pc_iterations=2.
# step=130, pc_iterations=2.
# step=131, pc_iterations=2.
# step=132, pc_iterations=2.
# step=133, pc_iterations=2.
# step=134, pc_iterations=2.
# step=135, pc_iterations=2.
# step=136, pc_iterations=2.
# step=137, pc_iterations=2.
# step=138, pc_iterations=2.
# step=139, pc_iterations=2.
# step=140, pc_iterations=2.
# step=141, pc_iterations=2.
# step=142, pc_iterations=2.
# step=143, pc_iterations=2.
# step=144, pc_iterations=2.
# step=145, pc_iterations=2.
# step=146, pc_iterations=2.
# step=147, pc_iterations=2.
# step=148, pc_iterations=2.
# step=149, pc_iterations=2.
# step=150, pc_iterations=2.
# step=151, pc_iterations=2.
# step=152, pc_iterations=2.
# step=153, pc_iterations=2.
# step=154, pc_iterations=2.
# step=155, pc_iterations=2.
# step=156, pc_iterations=2.
# step=157, pc_iterations=2.
# step=158, pc_iterations=2.
# step=159, pc_iterations=2.
# step=160, pc_iterations=2.
# step=161, pc_iterations=2.
# step=162, pc_iterations=2.
# step=163, pc_iterations=2.
# step=164, pc_iterations=2.
# step=165, pc_iterations=2.
# step=166, pc_iterations=2.
# step=167, pc_iterations=2.
# step=168, pc_iterations=2.
# step=169, pc_iterations=2.
# step=170, pc_iterations=2.
# step=171, pc_iterations=2.
# step=172, pc_iterations=2.
# step=173, pc_iterations=2.
# step=174, pc_iterations=2.
# step=175, pc_iterations=2.
# step=176, pc_iterations=2.
# step=177, pc_iterations=2.
# step=178, pc_iterations=2.
# step=179, pc_iterations=2.
# step=180, pc_iterations=2.
# step=181, pc_iterations=2.
# step=182, pc_iterations=2.
# step=183, pc_iterations=2.
# step=184, pc_iterations=2.
# step=185, pc_iterations=2.
# step=186, pc_iterations=2.

# %%
theta=(solverF.get_temperature_interface(3,0,1)-T_bot)/(T_f-T_bot)
print(theta)
sio.savemat(
    'numeric_res/kFDSN_avg%i.mat' % k,
    {
        'theta': theta,
        'avg_pc_its': avg_pc_iterations/(step+1),
        'N': (step+1)
    }
)
# Out:
# [0.08481885 0.07807178 0.07321713 0.06925155 0.06588123 0.06302578
#  0.0604826  0.05820792 0.05612994 0.05417578 0.05238661 0.05070225
#  0.04913033 0.04763987 0.04624055 0.04490965 0.04365163 0.0424473
#  0.04130248 0.04021387 0.03917215 0.03817873 0.03722427 0.03631341
#  0.03544318 0.03460976 0.03380705 0.0330383  0.03229846 0.03158884
#  0.03090873 0.03025423 0.02962493 0.02902201 0.02843817 0.02787889
#  0.02734206 0.02682604 0.02632741 0.02584854 0.025387   0.02494275
#  0.02451623 0.02410586 0.02371113 0.02333132 0.02296651 0.02261506
#  0.02227823 0.02195441 0.02164451 0.02134608 0.02106041 0.02078776
#  0.02052602 0.02027707 0.02003855 0.01981228 0.01959724 0.01939277
#  0.01919995 0.01901783 0.01884731 0.01868684 0.01853803 0.0184007
#  0.01827348 0.01815878 0.01805474 0.01796266 0.01788255 0.01781419
#  0.01775916 0.01771617 0.01768698 0.01767083 0.01766992 0.01768343
#  0.01771181 0.01775758 0.01781934 0.01790033 0.01800039 0.01811982
#  0.01826209 0.01842786 0.01862018 0.01883943 0.01909055 0.0193775
#  0.01970111 0.02007177 0.02049032 0.02097654 0.02153452 0.02220564
#  0.02297686 0.02396949 0.02530263 0.02702487]
