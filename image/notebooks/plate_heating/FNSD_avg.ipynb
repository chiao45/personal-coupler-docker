# %%
from ovcg import *
from fesol import *
import numpy as np
import scipy.io as sio
from interface import DynamicUnderRelaxation, InterfaceData, RelativeCovergenceMonitor, AbsCovergenceMonitor

# %%
k=20
# problem discription:
# basically, with a fixed Pr=0.01 and Re=500, the k is the ratio between
# kappa_s/kappa_f, where kappa stands for conductivity coefficient.
assert k == 1 or k == 5 or k == 20

use_relax = True
use_solid_steady = False

# tolerance setting
tol = 1e-6
if tol > 1e-1:
    print('The tolerance is too large, this may lead to instability or low quality results')

# %%
# since this is a matching interface, we can create
# exact interface nodes mappings.
# this step is done offline
inodes = 100
s2f = np.zeros(inodes, dtype=int)
f2s = s2f.copy()
s2f[1] = inodes-1
start = inodes-2
for i in range(inodes-2):
    s2f[i+2] = start
    start = start - 1
count = 0
for i in range(inodes):
    f2s[s2f[i]] = i

# %%
# fluid solver
interface_grid = 3
interface_side = 0
interface_axis = 1

T_f = 350.0

solverF = Cgins()
solverF.read_cmd('fluid_inputs/fluid_flat_plate%i_fnsd.cmd' % k)
solverF.init_grid()
solverF.init_flux_interface(
    grid=interface_grid,
    side=interface_side,
    axis=interface_axis
)
solverF.init_solver(debug=0, logname='fluid_outputs/dummy')
fluid_ofile = VtkFile('fluid_outputs/resFNSD_avg%i.pvd' % k)

# %%
# solid solver
fixed_temp_tag = 2
adiabatic_tag = 3
interface_tag = 4

kappa = 100.0
rho = 1.0
Cp = 100.0
T_bot = 310.0

solverS = HeatSolver(kappa=kappa, rho=rho, Cp=Cp, steady=use_solid_steady, time_order=2)
solverS.output_file = 'solid_outputs/resFNSD_avg%i.pvd' % k
solverS.load_mesh('solid_inputs/solid_plate.msh')
solverS.set_initial_condition(T_bot)
solverS.define_adiabatic_bd(tag=adiabatic_tag)
solverS.define_const_temperature_bd(tag=fixed_temp_tag, value=T_bot)
solverS.define_temperature_interface(tag=interface_tag, init_values=T_bot)
solverS.init_solver()

# %%
# coupling data and setups
fluxF = InterfaceData(size=inodes, value=0.0)
fluxS = InterfaceData(size=inodes, value=0.0)
tempF = InterfaceData(size=inodes, value=T_f)
tempS = InterfaceData(size=inodes, value=T_bot)
thetaT = InterfaceData(size=inodes, value=0.0)

under_relax = DynamicUnderRelaxation(init_omega=1.0)
conv_mntr = RelativeCovergenceMonitor(tol=tol)
conv_solution = AbsCovergenceMonitor(tol=1e-4)

# maximum pc steps allowed
max_pc_steps = 200

# %%
# coupling timing information, use fixed time step for now
# Tfinal = 1.0
# N = 100
# dt = Tfinal/N
dt = 0.05
Nmax = 2000
t = 0.0
avg_pc_iterations = 0.0
flog = open('FNSD_avg%i.log' % k, mode='w')
flog.write('Fluid Neumann with solid Dirichlet setting, study case: %i\n' % k)
flog.close()
flog = open('FNSD_avg%i.log' % k, mode='a')

tempf_prev = tempF.curr.copy()
fluxs_prev = fluxS.curr.copy()

# %%
# begin to couple
for step in range(Nmax):
    t += dt
    
    pc_counts = 0
    
    # back up solutions
    solverF.backup_current_solutions()
    solverS.backup()
    
    tempf_prev[:] = tempF.curr
    fluxs_prev[:] = fluxS.curr
    
    # mapping
    fluxF.curr[:] = fluxS.curr[s2f]
    
    solverF.put_heat_flux_interface(
        grid=interface_grid,
        side=interface_side,
        axis=interface_axis,
        data=fluxF.curr
    )
    
    while True:
        fluxF.backup()
        tempF.backup()
        
        # advance fluid
        solverF.advance(t=t, dt=dt)
        # retrieve fluid interface temperature
        tempF.curr[:] = solverF.get_temperature_interface(
            grid=interface_grid,
            side=interface_side,
            axis=interface_axis
        )
        
        # mapping
        tempS.curr[:] = 0.5*(tempF.curr[f2s]+tempf_prev[f2s])
        
        solverS.update_temperature_interface(interface_tag, tempS.curr)
        
        # advance solid
        solverS.advance(t=t, dt=dt)
        # retrieve solid interface flux
        fluxS.curr[:] = solverS.get_interface_flux(tag=interface_tag)
        
        # mapping
        fluxF.curr[:] = fluxS.curr[s2f] 
        
        # update residual
        fluxF.update_res()
        
        # test convergence
        is_conv = conv_mntr.determine_convergence(fluxF)
        if is_conv or pc_counts >= max_pc_steps:
            break
        else:
            # if not converge, then underrelaxation and update to solid then restore
            if use_relax:
                under_relax.determine_omega(fluxF)
                under_relax.update_solution(fluxF)
            solverF.put_heat_flux_interface(
                grid=interface_grid,
                side=interface_side,
                axis=interface_axis,
                data=0.5*(fluxF.curr+fluxs_prev[s2f])
            )
            solverF.restore_previous_solutions()
            solverS.restore()
            pc_counts = pc_counts + 1

    # outputs
    msg = 'step=%i, pc_iterations=%i.' % (step, pc_counts)
    print(msg)
    flog.write(msg+'\n')
    avg_pc_iterations += pc_counts
    if step % 50 == 0 or step == Nmax-1:
        solverS.write()
        fluid_ofile.write(solverF, t)
    thetaT.backup()
    thetaT.curr[:] = (solverF.get_temperature_interface(3,0,1)-T_bot)/(T_f-T_bot)
    thetaT.update_res()
    is_conv = conv_solution.determine_convergence(thetaT)
    if is_conv:
        if step % 50 and step != Nmax-1:
            solverS.write()
            fluid_ofile.write(solverF, t)
        break
    
flog.close()
# Out:
# step=0, pc_iterations=14.
# step=1, pc_iterations=15.
# step=2, pc_iterations=14.
# step=3, pc_iterations=15.
# step=4, pc_iterations=14.
# step=5, pc_iterations=15.
# step=6, pc_iterations=15.
# step=7, pc_iterations=16.
# step=8, pc_iterations=14.
# step=9, pc_iterations=15.
# step=10, pc_iterations=15.
# step=11, pc_iterations=15.
# step=12, pc_iterations=15.
# step=13, pc_iterations=16.
# step=14, pc_iterations=14.
# step=15, pc_iterations=15.
# step=16, pc_iterations=14.
# step=17, pc_iterations=15.
# step=18, pc_iterations=14.
# step=19, pc_iterations=15.
# step=20, pc_iterations=15.
# step=21, pc_iterations=15.
# step=22, pc_iterations=15.
# step=23, pc_iterations=15.
# step=24, pc_iterations=15.
# step=25, pc_iterations=15.
# step=26, pc_iterations=15.
# step=27, pc_iterations=15.
# step=28, pc_iterations=15.
# step=29, pc_iterations=15.
# step=30, pc_iterations=15.
# step=31, pc_iterations=15.
# step=32, pc_iterations=14.
# step=33, pc_iterations=15.
# step=34, pc_iterations=14.
# step=35, pc_iterations=15.
# step=36, pc_iterations=14.
# step=37, pc_iterations=15.
# step=38, pc_iterations=14.
# step=39, pc_iterations=15.
# step=40, pc_iterations=14.
# step=41, pc_iterations=15.
# step=42, pc_iterations=14.
# step=43, pc_iterations=15.
# step=44, pc_iterations=14.
# step=45, pc_iterations=15.
# step=46, pc_iterations=14.
# step=47, pc_iterations=15.
# step=48, pc_iterations=14.
# step=49, pc_iterations=15.
# step=50, pc_iterations=14.
# step=51, pc_iterations=15.
# step=52, pc_iterations=14.
# step=53, pc_iterations=15.
# step=54, pc_iterations=15.
# step=55, pc_iterations=15.
# step=56, pc_iterations=15.
# step=57, pc_iterations=16.
# step=58, pc_iterations=15.
# step=59, pc_iterations=16.
# step=60, pc_iterations=15.
# step=61, pc_iterations=16.
# step=62, pc_iterations=15.
# step=63, pc_iterations=16.
# step=64, pc_iterations=15.
# step=65, pc_iterations=16.
# step=66, pc_iterations=15.
# step=67, pc_iterations=16.
# step=68, pc_iterations=15.
# step=69, pc_iterations=16.
# step=70, pc_iterations=15.
# step=71, pc_iterations=16.
# step=72, pc_iterations=15.
# step=73, pc_iterations=16.
# step=74, pc_iterations=15.
# step=75, pc_iterations=16.
# step=76, pc_iterations=15.
# step=77, pc_iterations=16.
# step=78, pc_iterations=15.
# step=79, pc_iterations=16.
# step=80, pc_iterations=15.
# step=81, pc_iterations=16.
# step=82, pc_iterations=15.
# step=83, pc_iterations=16.
# step=84, pc_iterations=15.
# step=85, pc_iterations=15.
# step=86, pc_iterations=15.
# step=87, pc_iterations=15.
# step=88, pc_iterations=15.
# step=89, pc_iterations=15.
# step=90, pc_iterations=15.
# step=91, pc_iterations=15.
# step=92, pc_iterations=15.
# step=93, pc_iterations=15.
# step=94, pc_iterations=15.
# step=95, pc_iterations=15.
# step=96, pc_iterations=15.
# step=97, pc_iterations=15.
# step=98, pc_iterations=15.
# step=99, pc_iterations=15.
# step=100, pc_iterations=15.
# step=101, pc_iterations=15.
# step=102, pc_iterations=15.
# step=103, pc_iterations=15.
# step=104, pc_iterations=15.
# step=105, pc_iterations=15.
# step=106, pc_iterations=15.
# step=107, pc_iterations=15.
# step=108, pc_iterations=14.
# step=109, pc_iterations=15.
# step=110, pc_iterations=14.
# step=111, pc_iterations=15.
# step=112, pc_iterations=14.
# step=113, pc_iterations=15.
# step=114, pc_iterations=14.
# step=115, pc_iterations=15.
# step=116, pc_iterations=14.
# step=117, pc_iterations=15.
# step=118, pc_iterations=14.
# step=119, pc_iterations=15.
# step=120, pc_iterations=14.
# step=121, pc_iterations=15.
# step=122, pc_iterations=14.
# step=123, pc_iterations=15.
# step=124, pc_iterations=14.
# step=125, pc_iterations=15.
# step=126, pc_iterations=14.
# step=127, pc_iterations=15.
# step=128, pc_iterations=14.
# step=129, pc_iterations=15.
# step=130, pc_iterations=14.
# step=131, pc_iterations=15.
# step=132, pc_iterations=14.
# step=133, pc_iterations=14.
# step=134, pc_iterations=14.
# step=135, pc_iterations=14.
# step=136, pc_iterations=14.
# step=137, pc_iterations=14.
# step=138, pc_iterations=14.
# step=139, pc_iterations=14.
# step=140, pc_iterations=14.
# step=141, pc_iterations=14.
# step=142, pc_iterations=14.
# step=143, pc_iterations=14.
# step=144, pc_iterations=14.
# step=145, pc_iterations=14.
# step=146, pc_iterations=14.
# step=147, pc_iterations=14.
# step=148, pc_iterations=14.
# step=149, pc_iterations=14.
# step=150, pc_iterations=14.
# step=151, pc_iterations=14.
# step=152, pc_iterations=14.
# step=153, pc_iterations=14.
# step=154, pc_iterations=14.
# step=155, pc_iterations=14.
# step=156, pc_iterations=14.
# step=157, pc_iterations=14.
# step=158, pc_iterations=14.
# step=159, pc_iterations=14.
# step=160, pc_iterations=14.
# step=161, pc_iterations=14.
# step=162, pc_iterations=14.
# step=163, pc_iterations=14.
# step=164, pc_iterations=14.
# step=165, pc_iterations=14.
# step=166, pc_iterations=14.
# step=167, pc_iterations=14.
# step=168, pc_iterations=14.
# step=169, pc_iterations=14.
# step=170, pc_iterations=14.
# step=171, pc_iterations=14.
# step=172, pc_iterations=14.
# step=173, pc_iterations=14.
# step=174, pc_iterations=14.
# step=175, pc_iterations=14.
# step=176, pc_iterations=14.
# step=177, pc_iterations=14.
# step=178, pc_iterations=14.
# step=179, pc_iterations=14.
# step=180, pc_iterations=14.
# step=181, pc_iterations=14.
# step=182, pc_iterations=14.
# step=183, pc_iterations=14.
# step=184, pc_iterations=14.
# step=185, pc_iterations=14.
# step=186, pc_iterations=14.
# step=187, pc_iterations=14.
# step=188, pc_iterations=14.
# step=189, pc_iterations=14.
# step=190, pc_iterations=14.
# step=191, pc_iterations=14.
# step=192, pc_iterations=14.
# step=193, pc_iterations=14.
# step=194, pc_iterations=14.
# step=195, pc_iterations=14.
# step=196, pc_iterations=14.
# step=197, pc_iterations=14.
# step=198, pc_iterations=14.
# step=199, pc_iterations=14.
# step=200, pc_iterations=14.
# step=201, pc_iterations=14.
# step=202, pc_iterations=14.
# step=203, pc_iterations=14.
# step=204, pc_iterations=14.
# step=205, pc_iterations=14.
# step=206, pc_iterations=14.
# step=207, pc_iterations=14.
# step=208, pc_iterations=14.
# step=209, pc_iterations=14.
# step=210, pc_iterations=14.
# step=211, pc_iterations=14.
# step=212, pc_iterations=14.
# step=213, pc_iterations=14.
# step=214, pc_iterations=14.
# step=215, pc_iterations=14.
# step=216, pc_iterations=14.
# step=217, pc_iterations=14.
# step=218, pc_iterations=14.
# step=219, pc_iterations=14.
# step=220, pc_iterations=14.
# step=221, pc_iterations=14.
# step=222, pc_iterations=14.
# step=223, pc_iterations=14.
# step=224, pc_iterations=14.
# step=225, pc_iterations=14.
# step=226, pc_iterations=14.
# step=227, pc_iterations=14.
# step=228, pc_iterations=14.
# step=229, pc_iterations=14.
# step=230, pc_iterations=14.
# step=231, pc_iterations=14.
# step=232, pc_iterations=14.
# step=233, pc_iterations=14.
# step=234, pc_iterations=14.
# step=235, pc_iterations=14.
# step=236, pc_iterations=14.
# step=237, pc_iterations=14.
# step=238, pc_iterations=14.
# step=239, pc_iterations=14.
# step=240, pc_iterations=14.
# step=241, pc_iterations=14.
# step=242, pc_iterations=14.
# step=243, pc_iterations=14.
# step=244, pc_iterations=14.
# step=245, pc_iterations=14.
# step=246, pc_iterations=14.
# step=247, pc_iterations=14.
# step=248, pc_iterations=14.
# step=249, pc_iterations=14.
# step=250, pc_iterations=14.
# step=251, pc_iterations=14.
# step=252, pc_iterations=14.
# step=253, pc_iterations=14.
# step=254, pc_iterations=14.
# step=255, pc_iterations=14.
# step=256, pc_iterations=14.
# step=257, pc_iterations=14.
# step=258, pc_iterations=14.
# step=259, pc_iterations=14.
# step=260, pc_iterations=14.
# step=261, pc_iterations=14.
# step=262, pc_iterations=14.
# step=263, pc_iterations=14.
# step=264, pc_iterations=14.
# step=265, pc_iterations=14.
# step=266, pc_iterations=14.
# step=267, pc_iterations=14.
# step=268, pc_iterations=14.
# step=269, pc_iterations=14.
# step=270, pc_iterations=14.
# step=271, pc_iterations=14.
# step=272, pc_iterations=14.
# step=273, pc_iterations=14.
# step=274, pc_iterations=14.
# step=275, pc_iterations=14.
# step=276, pc_iterations=14.
# step=277, pc_iterations=14.
# step=278, pc_iterations=14.
# step=279, pc_iterations=14.
# step=280, pc_iterations=14.
# step=281, pc_iterations=14.
# step=282, pc_iterations=14.
# step=283, pc_iterations=14.
# step=284, pc_iterations=14.
# step=285, pc_iterations=14.
# step=286, pc_iterations=14.
# step=287, pc_iterations=14.
# step=288, pc_iterations=14.
# step=289, pc_iterations=14.
# step=290, pc_iterations=14.
# step=291, pc_iterations=14.
# step=292, pc_iterations=14.

# %%
theta=(solverF.get_temperature_interface(3,0,1)-T_bot)/(T_f-T_bot)
print(theta)
sio.savemat(
    'numeric_res/kFNSD_avg%i.mat' % k,
    {
        'theta': theta,
        'avg_pc_its': avg_pc_iterations/(step+1),
        'N': (step+1)
    }
)
# Out:
# [0.0756496  0.06934048 0.06428627 0.06140833 0.05894794 0.05667416
#  0.05465417 0.05281582 0.05103706 0.04944556 0.04795116 0.04655751
#  0.04520038 0.04393345 0.04272021 0.04158417 0.04047424 0.03942371
#  0.03842737 0.03745475 0.03653312 0.03563978 0.03478108 0.03396438
#  0.03316666 0.03240356 0.03165986 0.03096021 0.03029133 0.02963617
#  0.02900001 0.02839227 0.02780139 0.02722833 0.02667701 0.02614973
#  0.02563155 0.02513414 0.02464619 0.02418396 0.02374015 0.02331217
#  0.02289362 0.02248686 0.02209223 0.02171158 0.02133977 0.02098556
#  0.02064371 0.02030493 0.019981   0.01967055 0.01937009 0.01907703
#  0.01879613 0.01852133 0.01825979 0.01800563 0.01775819 0.01752417
#  0.01730017 0.01707833 0.01686842 0.01666868 0.01647959 0.01629379
#  0.01612128 0.01595594 0.01580324 0.01565578 0.01551207 0.01538255
#  0.01526532 0.01515017 0.01504856 0.01495742 0.01487904 0.01480665
#  0.01474917 0.01470113 0.01466883 0.01464703 0.01463559 0.01463448
#  0.01465195 0.01468726 0.01473397 0.01480474 0.01489662 0.01500767
#  0.01514497 0.0153087  0.0155059  0.01572793 0.01599852 0.01632283
#  0.01675865 0.01724058 0.0180885  0.01916006]
